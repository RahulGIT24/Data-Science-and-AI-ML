# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 2 Main datatypes
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# Series -> 1-dimensional

# %%
colours = pd.Series(["Red","Blue","White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# Dataframe -> 2 dimensional

# %%
car_data = pd.DataFrame({"Car Make":series,"Colour":colours})
car_data
# Out:
#   Car Make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import Data
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv('exported_car_sales.csv',index=False)

# %%
exported_car_sales = pd.read_csv("exported_car_sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes

# function
# car_sales.to_csv(path)
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True) # Remember numeric_only
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000,1200,200])
car_prices.mean(numeric_only=True)
# Out:
# 1466.6666666666667

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
my_series = pd.Series([12,2,3])
my_series.mean(numeric_only=True)
# Out:
# 5.666666666666667

# %% [markdown]
# ## Viewing and Selecting Data

# %%
car_sales.head() # 5 rows of csv file
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail() # 5 last rows of csv file
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.head(7) # first 7 rows
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# .loc and .iloc
animal = pd.Series(["Cat","Dog","Panda","Python"],index=[0,3,2,3]) # custom index

# %%
animal
# Out:
# 0       Cat
# 3       Dog
# 2     Panda
# 3    Python
# dtype: object

# %%
animal.loc[3] # get the value at index numbers
# loc refers to index
# Out:
# 3       Dog
# 3    Python
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# iloc refers to position
animal.iloc[2]
# Out:
# 'Panda'

# %%
animal
# Out:
# 0       Cat
# 3       Dog
# 2     Panda
# 3    Python
# dtype: object

# %%
car_sales.iloc[3] # index is in series
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
animal.iloc[:3] # return elem from position 0 to 2, 3 is excluded
# Out:
# 0      Cat
# 3      Dog
# 2    Panda
# dtype: object

# %%
animal
# Out:
# 0       Cat
# 3       Dog
# 2     Panda
# 3    Python
# dtype: object

# %%
car_sales.loc[:3] # Returns index from 0 to 3
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
# Selectin column
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make # another way of selecting column
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Odometer (KM) # This not works when column name has space
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_47466/2975113975.py in ?()
# ----> 1 car_sales.Odometer (KM) # This not works when column name has space
#
# ~/Coding/Data Science/Course/env/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
car_sales['Odometer (KM)'] # This will work for spaces

# %%
# boolean indexing
# seleting df by filtering
car_sales[car_sales['Make'] == 'Toyota']

# %%
pd.crosstab(car_sales["Make"],car_sales['Doors'])

# %%
car_sales

# %%
# groupby
car_sales.groupby(["Make"]).mean(numeric_only=True)

# %%
car_sales['Odometer (KM)'].plot()

# %%
car_sales

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].plot()

# %%
car_sales["Price"].dtype

# %%
car_sales["Price"] = car_sales["Price"].astype(str)
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,\.]', '', regex=True)

# %%
car_sales

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales["Price"].dtype

# %%
car_sales["Price"].plot()

# %%
car_sales["Price"].hist()

# %% [markdown]
# ## Manipulating Data

# %%
car_sales['Make'].str.lower()

# %%
car_sales

# %%
car_sales["Make"] = car_sales["Make"].str.lower() # Column name should be lowered case

# %%
car_sales["Make"]

# %%
car_sales

# %%
# Missing data
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing

# %%
# car_sales_missing["Odometer"].mean()
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
# inplace parameter
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(),inplace=True)

# %%
car_sales_missing

# %%
# ignore missing values
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Column for series
seats_column = pd.Series([5,5,5,5,5])
car_sales['Seats'] = seats_column

# %%
car_sales # only first 5 seats were filled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales['Seats'].fillna(5,inplace=True)
# Out:
# /tmp/ipykernel_47466/4074521166.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales['Seats'].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
# Column from python list
fuel_economy = [7.5,8.9,12,2.3,11.0,1,2,3,4,9.4] # not less than 10 values cause df has 10 rows
car_sales["Fuel Per 100 KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 100 KM
# 0  Toyota  White         150043      4   $4,000.00    5.0              7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0              8.9
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             12.0
# 3     BMW  Black          11179      5  $22,000.00    5.0              2.3
# 4  Nissan  White         213095      4   $3,500.00    5.0             11.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              1.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0              3.0
# 8  Toyota  White          60000      4   $6,250.00    5.0              4.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.4

# %%
car_sales["Total Fuel Used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel Per 100 KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0              7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0              8.9
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             12.0
# 3     BMW  Black          11179      5  $22,000.00    5.0              2.3
# 4  Nissan  White         213095      4   $3,500.00    5.0             11.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              1.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0              3.0
# 8  Toyota  White          60000      4   $6,250.00    5.0              4.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.4
#
#    Total Fuel Used
# 0        11253.225
# 1         7823.011
# 2         3905.880
# 3          257.117
# 4        23440.450
# 5          992.130
# ...

# %%
# Create a column from single value
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0              7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0              8.9
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             12.0
# 3     BMW  Black          11179      5  $22,000.00    5.0              2.3
# 4  Nissan  White         213095      4   $3,500.00    5.0             11.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              1.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0              3.0
# 8  Toyota  White          60000      4   $6,250.00    5.0              4.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.4
#
#    Total Fuel Used  Number of Wheels
# 0        11253.225                 4
# 1         7823.011                 4
# ...

# %%
car_sales["Passed Road Safety"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0              7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0              8.9
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             12.0
# 3     BMW  Black          11179      5  $22,000.00    5.0              2.3
# 4  Nissan  White         213095      4   $3,500.00    5.0             11.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              1.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0              3.0
# 8  Toyota  White          60000      4   $6,250.00    5.0              4.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.4
#
#    Total Fuel Used  Number of Wheels  Passed Road Safety
# 0        11253.225                 4                True
# ...

# %%
car_sales = car_sales.drop(0,axis=0)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 100 KM  \
# 1   Honda    Red          87899      4   $5,000.00    5.0              8.9
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             12.0
# 3     BMW  Black          11179      5  $22,000.00    5.0              2.3
# 4  Nissan  White         213095      4   $3,500.00    5.0             11.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              1.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0              3.0
# 8  Toyota  White          60000      4   $6,250.00    5.0              4.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.4
#
#    Total Fuel Used  Number of Wheels  Passed Road Safety
# 1         7823.011                 4                True
# 2         3905.880                 4                True
# ...

# %%
car_sales.sample(frac=0.5) # Shuffle 50% data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel Per 100 KM  \
# 9  Nissan  White          31600      4  $9,700.00    5.0              9.4
# 1   Honda    Red          87899      4  $5,000.00    5.0              8.9
# 4  Nissan  White         213095      4  $3,500.00    5.0             11.0
# 5  Toyota  Green          99213      4  $4,500.00    5.0              1.0
#
#    Total Fuel Used  Number of Wheels  Passed Road Safety
# 9         2970.400                 4                True
# 1         7823.011                 4                True
# 4        23440.450                 4                True
# 5          992.130                 4                True

# %%
car_sales_shuffled = car_sales.sample(frac=1) # Shuffle data (Change order of data)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 100 KM  \
# 3     BMW  Black          11179      5  $22,000.00    5.0              2.3
# 7   Honda   Blue          54738      4   $7,000.00    5.0              3.0
# 4  Nissan  White         213095      4   $3,500.00    5.0             11.0
# 1   Honda    Red          87899      4   $5,000.00    5.0              8.9
# 6   Honda   Blue          45698      4   $7,500.00    5.0              2.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              1.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             12.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.4
# 8  Toyota  White          60000      4   $6,250.00    5.0              4.0
#
#    Total Fuel Used  Number of Wheels  Passed Road Safety
# 3          257.117                 4                True
# 7         1642.140                 4                True
# ...

# %%
car_sales_shuffled.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel Per 100 KM  \
# 4  Nissan  White         213095      4  $3,500.00    5.0             11.0
# 8  Toyota  White          60000      4  $6,250.00    5.0              4.0
#
#    Total Fuel Used  Number of Wheels  Passed Road Safety
# 4         23440.45                 4                True
# 8          2400.00                 4                True

# %%
# Reset the index of shuffled data
car_sales_shuffled.reset_index(drop = True)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 100 KM  \
# 0     BMW  Black          11179      5  $22,000.00    5.0              2.3
# 1   Honda   Blue          54738      4   $7,000.00    5.0              3.0
# 2  Nissan  White         213095      4   $3,500.00    5.0             11.0
# 3   Honda    Red          87899      4   $5,000.00    5.0              8.9
# 4   Honda   Blue          45698      4   $7,500.00    5.0              2.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              1.0
# 6  Toyota   Blue          32549      3   $7,000.00    5.0             12.0
# 7  Nissan  White          31600      4   $9,700.00    5.0              9.4
# 8  Toyota  White          60000      4   $6,250.00    5.0              4.0
#
#    Total Fuel Used  Number of Wheels  Passed Road Safety
# 0          257.117                 4                True
# 1         1642.140                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 100 KM  \
# 1   Honda    Red          87899      4   $5,000.00    5.0              8.9
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             12.0
# 3     BMW  Black          11179      5  $22,000.00    5.0              2.3
# 4  Nissan  White         213095      4   $3,500.00    5.0             11.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0              1.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0              2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0              3.0
# 8  Toyota  White          60000      4   $6,250.00    5.0              4.0
# 9  Nissan  White          31600      4   $9,700.00    5.0              9.4
#
#    Total Fuel Used  Number of Wheels  Passed Road Safety
# 1         7823.011                 4                True
# 2         3905.880                 4                True
# ...

# %%
# Apply function to column
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel Per 100 KM  \
# 1   Honda    Red      54936.875      4   $5,000.00    5.0              8.9
# 2  Toyota   Blue      20343.125      3   $7,000.00    5.0             12.0
# 3     BMW  Black       6986.875      5  $22,000.00    5.0              2.3
# 4  Nissan  White     133184.375      4   $3,500.00    5.0             11.0
# 5  Toyota  Green      62008.125      4   $4,500.00    5.0              1.0
# 6   Honda   Blue      28561.250      4   $7,500.00    5.0              2.0
# 7   Honda   Blue      34211.250      4   $7,000.00    5.0              3.0
# 8  Toyota  White      37500.000      4   $6,250.00    5.0              4.0
# 9  Nissan  White      19750.000      4   $9,700.00    5.0              9.4
#
#    Total Fuel Used  Number of Wheels  Passed Road Safety
# 1         7823.011                 4                True
# 2         3905.880                 4                True
# ...
