# %%
import  pandas as  pd

# %%
res = pd.read_csv("https://phantombuster.s3.amazonaws.com/crtoUNrBf08/5wPuUtl3IphVqqgDBp4suQ/result.csv",dtype=str)

# %%
selected_columns = ["name","profileUrl","job","currentJob","profileImageUrl","location","connectionDegree","sharedConnections","category","certifications","pastJob","summary"]

# %%
res = res[selected_columns]
res['locContainerID'] = 21
res['isSelected'] = 0

# %%
df = pd.DataFrame(res)

# %%
df.head()
# Out:
#              name                                         profileUrl  \
# 0    Ayushi Gupta             https://www.linkedin.com/in/ayushi1111
# 1  Chavisha Arora  https://www.linkedin.com/in/chavisha-arora-86b...
# 2  Nishant Bharti         https://www.linkedin.com/in/nishant-bharti
# 3      Libin Jose    https://www.linkedin.com/in/libin-jose-41464ba6
# 4        Ambir P.             https://www.linkedin.com/in/ambirpatel
#
#                                                  job  \
# 0  Machine learning |Deep learning| Btech AI &ML|...
# 1         Machine Learning Engineer II @ExpediaGroup
# 2  Data Scientist | Ex-HiLabs | Machine Learning ...
# 3                    Machine Learning & NLP Engineer
# 4                Machine Learning Engineer @ Cargill
#
#                                       currentJob  \
# 0         Machine Learning Intern at Prodigal AI
# 1  Machine Learning Engineer II at Expedia Group
# 2                                            NaN
# ...

# %%
df  = df.convert_dtypes()

# %%
df.fillna("None",inplace=True)
# Out:
# name                 string[python]
# profileUrl           string[python]
# job                  string[python]
# currentJob           string[python]
# profileImageUrl      string[python]
# location             string[python]
# connectionDegree     string[python]
# sharedConnections    string[python]
# category             string[python]
# certifications       string[python]
# pastJob              string[python]
# summary              string[python]
# locContainerID                Int64
# isSelected                    Int64
# dtype: object

# %%
df = df.fillna('None')

# %%
df
# Out:
#                            name  \
# 0                  Ayushi Gupta
# 1                Chavisha Arora
# 2                Nishant Bharti
# 3                    Libin Jose
# 4                      Ambir P.
# ..                          ...
# 994                 Aryan Monga
# 995          Shubham Khandelwal
# 996  Kajol Kiran Katyayini Soma
# 997            Vishal Bhatnagar
# 998             Bhupender Yadav
#
#                                             profileUrl  \
# 0               https://www.linkedin.com/in/ayushi1111
# 1    https://www.linkedin.com/in/chavisha-arora-86b...
# 2           https://www.linkedin.com/in/nishant-bharti
# 3      https://www.linkedin.com/in/libin-jose-41464ba6
# 4               https://www.linkedin.com/in/ambirpatel
# ..                                                 ...
# 994  https://www.linkedin.com/in/aryan-monga-472972209
# 995    https://www.linkedin.com/in/shubham-khandelwal-
# 996  https://www.linkedin.com/in/kajol-kiran-katyay...
# ...

# %%
data = [
    {
        "firstName": "Ranjodh",
        "fullName": "Ranjodh Singh",
        "profileUrl": "https://www.linkedin.com/in/singhranjodh",
        "job": "Machine Learning Engineer",
        "currentJob": "Machine Learning Engineer at Leena AI",
        "profileImageUrl": "https://media.licdn.com/dms/image/C5103AQHTfP-jFsUkBg/profile-displayphoto-shrink_100_100/0/1553532854685?e=1724889600&v=beta&t=70dDCjBbzEjZNQK10Tx5qudJuanV1CAn9TCxOi3yJZM",
        "location": "Delhi, India",
        "connectionDegree": "3rd",
        "category": "People"
    },
    # Add more simulated data entries for other profiles if needed
]

# %%
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#   firstName       fullName                                profileUrl  \
# 0   Ranjodh  Ranjodh Singh  https://www.linkedin.com/in/singhranjodh
#
#                          job                             currentJob  \
# 0  Machine Learning Engineer  Machine Learning Engineer at Leena AI
#
#                                      profileImageUrl      location  \
# 0  https://media.licdn.com/dms/image/C5103AQHTfP-...  Delhi, India
#
#   connectionDegree category
# 0              3rd   People

# %%
df1 = df1.convert_dtypes()
df1
# Out:
#   firstName       fullName                                profileUrl  \
# 0   Ranjodh  Ranjodh Singh  https://www.linkedin.com/in/singhranjodh
#
#                          job                             currentJob  \
# 0  Machine Learning Engineer  Machine Learning Engineer at Leena AI
#
#                                      profileImageUrl      location  \
# 0  https://media.licdn.com/dms/image/C5103AQHTfP-...  Delhi, India
#
#   connectionDegree category
# 0              3rd   People

# %%
df1.dtypes
# Out:
# firstName           string[python]
# fullName            string[python]
# profileUrl          string[python]
# job                 string[python]
# currentJob          string[python]
# profileImageUrl     string[python]
# location            string[python]
# connectionDegree    string[python]
# category            string[python]
# dtype: object
